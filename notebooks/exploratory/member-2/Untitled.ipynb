# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.preprocessing import OneHotEncoder
from sklearn.linear_model import LinearRegression
from sklearn.dummy import DummyRegressor
from sklearn.ensemble import RandomForestRegressor

# %%
# !pwd
# Out:
# /c/Users/avalencia/Documents/Flatiron/phase_2/project/bsc-phase-two-project/notebooks/exploratory/member-2

# %%
# Pull Dataframe
path = '../../../data/kc_house_data.csv'

df = pd.read_csv(path)
df
# Out:
#                id        date     price  bedrooms  bathrooms  sqft_living  \
# 0      7129300520  10/13/2014  221900.0         3       1.00         1180
# 1      6414100192   12/9/2014  538000.0         3       2.25         2570
# 2      5631500400   2/25/2015  180000.0         2       1.00          770
# 3      2487200875   12/9/2014  604000.0         4       3.00         1960
# 4      1954400510   2/18/2015  510000.0         3       2.00         1680
# ...           ...         ...       ...       ...        ...          ...
# 21592   263000018   5/21/2014  360000.0         3       2.50         1530
# 21593  6600060120   2/23/2015  400000.0         4       2.50         2310
# 21594  1523300141   6/23/2014  402101.0         2       0.75         1020
# 21595   291310100   1/16/2015  400000.0         3       2.50         1600
# 21596  1523300157  10/15/2014  325000.0         2       0.75         1020
#
#        sqft_lot  floors  waterfront  view  ...  grade  sqft_above  \
# ...

# %%
# Dropped the house with 33 bathrooms
df.drop(15856)
# Out:
#                id        date     price  bedrooms  bathrooms  sqft_living  \
# 0      7129300520  10/13/2014  221900.0         3       1.00         1180
# 1      6414100192   12/9/2014  538000.0         3       2.25         2570
# 2      5631500400   2/25/2015  180000.0         2       1.00          770
# 3      2487200875   12/9/2014  604000.0         4       3.00         1960
# 4      1954400510   2/18/2015  510000.0         3       2.00         1680
# ...           ...         ...       ...       ...        ...          ...
# 21592   263000018   5/21/2014  360000.0         3       2.50         1530
# 21593  6600060120   2/23/2015  400000.0         4       2.50         2310
# 21594  1523300141   6/23/2014  402101.0         2       0.75         1020
# 21595   291310100   1/16/2015  400000.0         3       2.50         1600
# 21596  1523300157  10/15/2014  325000.0         2       0.75         1020
#
#        sqft_lot  floors  waterfront  view  ...  grade  sqft_above  \
# ...

# %%
df.head()
# Out:
#            id        date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  10/13/2014  221900.0         3       1.00         1180
# 1  6414100192   12/9/2014  538000.0         3       2.25         2570
# 2  5631500400   2/25/2015  180000.0         2       1.00          770
# 3  2487200875   12/9/2014  604000.0         4       3.00         1960
# 4  1954400510   2/18/2015  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0         NaN   0.0  ...      7        1180            0.0
# 1      7242     2.0         0.0   0.0  ...      7        2170          400.0
# 2     10000     1.0         0.0   0.0  ...      6         770            0.0
# 3      5000     1.0         0.0   0.0  ...      7        1050          910.0
# 4      8080     1.0         0.0   0.0  ...      8        1680            0.0
#
#   yr_built  yr_renovated  zipcode      lat     long  sqft_living15  sqft_lot15
# ...

# %%
# Correlate price to other variables
df.corr()['price'].sort_values(ascending=False)
# Out:
# price            1.000000
# sqft_living      0.701917
# grade            0.667951
# sqft_above       0.605368
# sqft_living15    0.585241
# bathrooms        0.525906
# view             0.395734
# bedrooms         0.308787
# lat              0.306692
# waterfront       0.276295
# floors           0.256804
# yr_renovated     0.129599
# sqft_lot         0.089876
# sqft_lot15       0.082845
# yr_built         0.053953
# condition        0.036056
# long             0.022036
# id              -0.016772
# zipcode         -0.053402
# Name: price, dtype: float64

# %%
# Check null values
df.isna().sum()
# Out:
# id                  0
# date                0
# price               0
# bedrooms            0
# bathrooms           0
# sqft_living         0
# sqft_lot            0
# floors              0
# waterfront       2376
# view               63
# condition           0
# grade               0
# sqft_above          0
# sqft_basement       0
# yr_built            0
# yr_renovated     3842
# zipcode             0
# lat                 0
# long                0
# sqft_living15       0
# sqft_lot15          0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21597 entries, 0 to 21596
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             21597 non-null  int64
#  1   date           21597 non-null  object
#  2   price          21597 non-null  float64
#  3   bedrooms       21597 non-null  int64
#  4   bathrooms      21597 non-null  float64
#  5   sqft_living    21597 non-null  int64
#  6   sqft_lot       21597 non-null  int64
#  7   floors         21597 non-null  float64
#  8   waterfront     19221 non-null  float64
#  9   view           21534 non-null  float64
#  10  condition      21597 non-null  int64
#  11  grade          21597 non-null  int64
#  12  sqft_above     21597 non-null  int64
#  13  sqft_basement  21597 non-null  object
#  14  yr_built       21597 non-null  int64
#  15  yr_renovated   17755 non-null  float64
#  16  zipcode        21597 non-null  int64
# ...

# %%
# Creating dataframe with only price and bathrooms column
df = df.loc[:, ['price', 'bathrooms']]
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21597 entries, 0 to 21596
# Data columns (total 2 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   price      21597 non-null  float64
#  1   bathrooms  21597 non-null  float64
# dtypes: float64(2)
# memory usage: 337.6 KB

# %%
df.describe()
# Out:
#               price     bathrooms
# count  2.159700e+04  21597.000000
# mean   5.402966e+05      2.115826
# std    3.673681e+05      0.768984
# min    7.800000e+04      0.500000
# 25%    3.220000e+05      1.750000
# 50%    4.500000e+05      2.250000
# 75%    6.450000e+05      2.500000
# max    7.700000e+06      8.000000

# %%
# Correlation
df.corr()
# Out:
#               price  bathrooms
# price      1.000000   0.525906
# bathrooms  0.525906   1.000000

# %%
plt.figure(figsize=(6,6))

X = df['bathrooms']
Y = df['price']

ax = plt.axes()
ax.scatter(X, Y, color='r', alpha=0.20)
ax.set_xlabel('Bathrooms')
ax.set_ylabel('Price')
plt.show();

# %%
sns.lmplot(x='bathrooms', y='price', data=df)
plt.show()

# %%
X = df['bathrooms']
Y = df['price']

plt.scatter(X, Y, color='r')

# %%
plt.plot(X, Y, 'o')
m, b = np.polyfit(X, Y, 1)

plt.plot(X, m*X + b);

# %%
df.bathrooms.describe()
# Out:
# count    21597.000000
# mean         2.115826
# std          0.768984
# min          0.500000
# 25%          1.750000
# 50%          2.250000
# 75%          2.500000
# max          8.000000
# Name: bathrooms, dtype: float64

# %%
import statsmodels.api as sm

model = sm.OLS(df["price"], sm.add_constant(df["bathrooms"])).fit()
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.277
# Model:                            OLS   Adj. R-squared:                  0.277
# Method:                 Least Squares   F-statistic:                     8256.
# Date:                Mon, 28 Jun 2021   Prob (F-statistic):               0.00
# Time:                        11:57:59   Log-Likelihood:            -3.0389e+05
# No. Observations:               21597   AIC:                         6.078e+05
# Df Residuals:                   21595   BIC:                         6.078e+05
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       8712.6518   6224.769      1.400      0.162   -3488.356    2.09e+04
# ...

# %%
model = sm.OLS(df['price'], df['bathrooms'])
results = model.fit()
print(results.summary())
# Out:
#                                  OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared (uncentered):                   0.771
# Model:                            OLS   Adj. R-squared (uncentered):              0.771
# Method:                 Least Squares   F-statistic:                          7.282e+04
# Date:                Mon, 28 Jun 2021   Prob (F-statistic):                        0.00
# Time:                        11:58:00   Log-Likelihood:                     -3.0390e+05
# No. Observations:               21597   AIC:                                  6.078e+05
# Df Residuals:                   21596   BIC:                                  6.078e+05
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ...
